# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 590

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  f"{url}q={city}&appid={weather_api_key}" # YOUR CODE HERE
  
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json() # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]# YOUR CODE HERE
        city_lng = city_weather["coord"]["lon"]# YOUR CODE HERE
        city_max_temp = city_weather["main"]["temp_max"]# YOUR CODE HERE
        city_humidity = city_weather["main"]["humidity"]# YOUR CODE HERE
        city_clouds = city_weather["clouds"]["all"]# YOUR CODE HERE
        city_wind = city_weather["wind"]["speed"]# YOUR CODE HERE
        city_country = city_weather["sys"]["country"]# YOUR CODE HERE
        city_date = city_weather["dt"]# YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | west island
# Processing Record 2 of Set 1 | nova sintra
# Processing Record 3 of Set 1 | mayya
# Processing Record 4 of Set 1 | hawaiian paradise park
# Processing Record 5 of Set 1 | edinburgh of the seven seas
# Processing Record 6 of Set 1 | waitangi
# Processing Record 7 of Set 1 | stanley
# Processing Record 8 of Set 1 | itoman
# Processing Record 9 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 10 of Set 1 | cargados carajos
# City not found. Skipping...
# Processing Record 11 of Set 1 | karratha
# Processing Record 12 of Set 1 | utrik
# Processing Record 13 of Set 1 | maceio
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | saipan
# Processing Record 16 of Set 1 | qamdo
# Processing Record 17 of Set 1 | adamstown
# Processing Record 18 of Set 1 | pontianak
# Processing Record 19 of Set 1 | porto franco
# Processing Record 20 of Set 1 | belyy yar
# Processing Record 21 of Set 1 | grytviken
# Processing Record 22 of Set 1 | port-aux-francais
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 25 of Set 1 | blackmans bay
# Processing Record 26 of Set 1 | olonkinbyen
# Processing Record 27 of Set 1 | iskateley
# Processing Record 28 of Set 1 | puerto natales
# Processing Record 29 of Set 1 | ust'-kulom
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | tura
# Processing Record 32 of Set 1 | pemangkat
# Processing Record 33 of Set 1 | colonia
# Processing Record 34 of Set 1 | baissa
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | saint george's
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | kone
# Processing Record 40 of Set 1 | katsuren-haebaru
# Processing Record 41 of Set 1 | paradip garh
# Processing Record 42 of Set 1 | mount pearl
# Processing Record 43 of Set 1 | namibe
# Processing Record 44 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 45 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | invercargill
# Processing Record 48 of Set 1 | papatowai
# Processing Record 49 of Set 1 | kidal
# Processing Record 50 of Set 1 | bom jesus da lapa
# Processing Record 0 of Set 2 | whitehorse
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | serdar
# Processing Record 3 of Set 2 | juruti
# Processing Record 4 of Set 2 | tiksi
# Processing Record 5 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 6 of Set 2 | cedeira
# Processing Record 7 of Set 2 | ulladulla
# Processing Record 8 of Set 2 | kyakhta
# Processing Record 9 of Set 2 | fort mcmurray
# Processing Record 10 of Set 2 | carnarvon
# Processing Record 11 of Set 2 | atlantic city
# Processing Record 12 of Set 2 | tolanaro
# Processing Record 13 of Set 2 | kasongo-lunda
# Processing Record 14 of Set 2 | lerwick
# Processing Record 15 of Set 2 | ipueiras
# Processing Record 16 of Set 2 | zabol
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | udachny
# Processing Record 19 of Set 2 | ianca
# Processing Record 20 of Set 2 | sinop
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | adrar
# Processing Record 23 of Set 2 | klyuchi
# Processing Record 24 of Set 2 | kasempa
# Processing Record 25 of Set 2 | taos
# Processing Record 26 of Set 2 | dudinka
# Processing Record 27 of Set 2 | haiku-pauwela
# Processing Record 28 of Set 2 | san vicente
# Processing Record 29 of Set 2 | yoko
# Processing Record 30 of Set 2 | saint-hippolyte
# Processing Record 31 of Set 2 | iqaluit
# Processing Record 32 of Set 2 | preobrazheniye
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | margaret river
# Processing Record 35 of Set 2 | ordubad
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | guarapari
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | starkville
# Processing Record 40 of Set 2 | ancud
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | tapes
# Processing Record 43 of Set 2 | la sarre
# Processing Record 44 of Set 2 | ketchikan
# Processing Record 45 of Set 2 | holualoa
# Processing Record 46 of Set 2 | ouellah
# City not found. Skipping...
# Processing Record 47 of Set 2 | rambha
# Processing Record 48 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 49 of Set 2 | lesozavodsk
# Processing Record 0 of Set 3 | mount gambier
# Processing Record 1 of Set 3 | eyl
# Processing Record 2 of Set 3 | ola
# Processing Record 3 of Set 3 | dwarka
# Processing Record 4 of Set 3 | kavaratti
# Processing Record 5 of Set 3 | mo i rana
# Processing Record 6 of Set 3 | makhambet
# Processing Record 7 of Set 3 | quellon
# Processing Record 8 of Set 3 | tazacorte
# Processing Record 9 of Set 3 | vi thanh
# City not found. Skipping...
# Processing Record 10 of Set 3 | phang nga
# Processing Record 11 of Set 3 | khandyga
# Processing Record 12 of Set 3 | afif
# Processing Record 13 of Set 3 | koubia
# Processing Record 14 of Set 3 | peniche
# Processing Record 15 of Set 3 | talnakh
# Processing Record 16 of Set 3 | gallup
# Processing Record 17 of Set 3 | kotido
# Processing Record 18 of Set 3 | fort bragg
# Processing Record 19 of Set 3 | dzilam gonzalez
# Processing Record 20 of Set 3 | vavoua
# Processing Record 21 of Set 3 | hobyo
# Processing Record 22 of Set 3 | arar
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | albany
# Processing Record 25 of Set 3 | shache
# Processing Record 26 of Set 3 | anadyr
# Processing Record 27 of Set 3 | shillong
# Processing Record 28 of Set 3 | labytnangi
# Processing Record 29 of Set 3 | bubaque
# Processing Record 30 of Set 3 | kavieng
# Processing Record 31 of Set 3 | crane
# Processing Record 32 of Set 3 | egilsstadir
# Processing Record 33 of Set 3 | keflavik
# Processing Record 34 of Set 3 | sikonge
# Processing Record 35 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | abdurahmoni jomi
# Processing Record 38 of Set 3 | vorgashor
# Processing Record 39 of Set 3 | castillos
# Processing Record 40 of Set 3 | tocopilla
# Processing Record 41 of Set 3 | gamboula
# Processing Record 42 of Set 3 | raja
# Processing Record 43 of Set 3 | nikolayevsk-on-amure
# Processing Record 44 of Set 3 | dryden
# Processing Record 45 of Set 3 | russas
# Processing Record 46 of Set 3 | cockburn town
# Processing Record 47 of Set 3 | barakani
# Processing Record 48 of Set 3 | kewanee
# Processing Record 49 of Set 3 | thunder bay
# Processing Record 0 of Set 4 | hami
# Processing Record 1 of Set 4 | la punta
# Processing Record 2 of Set 4 | nizhnesortymskiy
# Processing Record 3 of Set 4 | enewetak
# Processing Record 4 of Set 4 | cide
# Processing Record 5 of Set 4 | aldan
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | bani walid
# Processing Record 8 of Set 4 | cao bang
# Processing Record 9 of Set 4 | cafayate
# Processing Record 10 of Set 4 | luziania
# Processing Record 11 of Set 4 | obo
# Processing Record 12 of Set 4 | turpan
# Processing Record 13 of Set 4 | howrah
# Processing Record 14 of Set 4 | nilsia
# Processing Record 15 of Set 4 | opuwo
# Processing Record 16 of Set 4 | bilibino
# Processing Record 17 of Set 4 | portmore
# Processing Record 18 of Set 4 | fort st. john
# Processing Record 19 of Set 4 | san patricio
# Processing Record 20 of Set 4 | ceerigaabo
# Processing Record 21 of Set 4 | zaozersk
# Processing Record 22 of Set 4 | meiganga
# Processing Record 23 of Set 4 | celestun
# Processing Record 24 of Set 4 | arvin
# Processing Record 25 of Set 4 | greenville
# Processing Record 26 of Set 4 | isafjordur
# Processing Record 27 of Set 4 | san pedro pochutla
# Processing Record 28 of Set 4 | avsallar
# Processing Record 29 of Set 4 | chonchi
# Processing Record 30 of Set 4 | twon-brass
# Processing Record 31 of Set 4 | fredericton
# Processing Record 32 of Set 4 | kataragama
# City not found. Skipping...
# Processing Record 33 of Set 4 | machico
# Processing Record 34 of Set 4 | hamilton
# Processing Record 35 of Set 4 | afaahiti
# Processing Record 36 of Set 4 | leava
# Processing Record 37 of Set 4 | nowy dwor mazowiecki
# Processing Record 38 of Set 4 | morales
# Processing Record 39 of Set 4 | lata
# Processing Record 40 of Set 4 | santa cruz
# Processing Record 41 of Set 4 | san pedro
# Processing Record 42 of Set 4 | gongchangling
# Processing Record 43 of Set 4 | puerto maldonado
# Processing Record 44 of Set 4 | hadibu
# Processing Record 45 of Set 4 | lenino
# Processing Record 46 of Set 4 | yuzhno-kurilsk
# Processing Record 47 of Set 4 | callao
# Processing Record 48 of Set 4 | port mathurin
# Processing Record 49 of Set 4 | arraial do cabo
# Processing Record 0 of Set 5 | plettenberg bay
# Processing Record 1 of Set 5 | uige
# Processing Record 2 of Set 5 | bodaybo
# Processing Record 3 of Set 5 | san fernando
# Processing Record 4 of Set 5 | wailua homesteads
# Processing Record 5 of Set 5 | paita
# Processing Record 6 of Set 5 | agat village
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | pop
# Processing Record 9 of Set 5 | bechar
# Processing Record 10 of Set 5 | ciudad lazaro cardenas
# Processing Record 11 of Set 5 | puerto deseado
# Processing Record 12 of Set 5 | pitimbu
# Processing Record 13 of Set 5 | polyarnyy
# Processing Record 14 of Set 5 | nuuk
# Processing Record 15 of Set 5 | tazovsky
# Processing Record 16 of Set 5 | motygino
# Processing Record 17 of Set 5 | taghazout
# Processing Record 18 of Set 5 | la passe
# Processing Record 19 of Set 5 | port lincoln
# Processing Record 20 of Set 5 | saint-pierre
# Processing Record 21 of Set 5 | fale old settlement
# Processing Record 22 of Set 5 | laojunmiao
# Processing Record 23 of Set 5 | saint-leu
# Processing Record 24 of Set 5 | chishmy
# Processing Record 25 of Set 5 | alappuzha
# Processing Record 26 of Set 5 | valparaiso
# Processing Record 27 of Set 5 | st. john's
# Processing Record 28 of Set 5 | maues
# Processing Record 29 of Set 5 | greymouth
# Processing Record 30 of Set 5 | toliara
# Processing Record 31 of Set 5 | rokytne
# Processing Record 32 of Set 5 | uturoa
# Processing Record 33 of Set 5 | faya-largeau
# Processing Record 34 of Set 5 | mogocha
# Processing Record 35 of Set 5 | dakhla
# Processing Record 36 of Set 5 | chui
# Processing Record 37 of Set 5 | qaqortoq
# Processing Record 38 of Set 5 | touros
# Processing Record 39 of Set 5 | college
# Processing Record 40 of Set 5 | yagry
# City not found. Skipping...
# Processing Record 41 of Set 5 | sayaxche
# Processing Record 42 of Set 5 | taungoo
# Processing Record 43 of Set 5 | ranohira
# City not found. Skipping...
# Processing Record 44 of Set 5 | sarkand
# Processing Record 45 of Set 5 | cabo san lucas
# Processing Record 46 of Set 5 | fada
# Processing Record 47 of Set 5 | san antonio de pale
# Processing Record 48 of Set 5 | brookings
# Processing Record 49 of Set 5 | pariaman
# Processing Record 0 of Set 6 | lakatoro
# Processing Record 1 of Set 6 | happy valley-goose bay
# Processing Record 2 of Set 6 | remire-montjoly
# Processing Record 3 of Set 6 | tual
# Processing Record 4 of Set 6 | beau vallon
# Processing Record 5 of Set 6 | isangel
# Processing Record 6 of Set 6 | barah
# Processing Record 7 of Set 6 | queenstown
# Processing Record 8 of Set 6 | hell-ville
# Processing Record 9 of Set 6 | sandnessjoen
# Processing Record 10 of Set 6 | morant bay
# Processing Record 11 of Set 6 | castelo do piaui
# Processing Record 12 of Set 6 | akonolinga
# Processing Record 13 of Set 6 | puerto armuelles
# Processing Record 14 of Set 6 | vila franca do campo
# Processing Record 15 of Set 6 | abadeh
# Processing Record 16 of Set 6 | wewak
# Processing Record 17 of Set 6 | la palma
# Processing Record 18 of Set 6 | cole harbour
# Processing Record 19 of Set 6 | dedovichi
# Processing Record 20 of Set 6 | athens
# Processing Record 21 of Set 6 | al khums
# Processing Record 22 of Set 6 | eldorado at santa fe
# Processing Record 23 of Set 6 | moia
# Processing Record 24 of Set 6 | karakulino
# Processing Record 25 of Set 6 | mareeba
# Processing Record 26 of Set 6 | port elizabeth
# Processing Record 27 of Set 6 | taksimo
# Processing Record 28 of Set 6 | guiuan
# Processing Record 29 of Set 6 | nouadhibou
# Processing Record 30 of Set 6 | anka
# Processing Record 31 of Set 6 | kudahuvadhoo
# Processing Record 32 of Set 6 | bangassou
# Processing Record 33 of Set 6 | fortuna
# Processing Record 34 of Set 6 | moralillo
# Processing Record 35 of Set 6 | lospalos
# Processing Record 36 of Set 6 | kuta
# Processing Record 37 of Set 6 | selfoss
# Processing Record 38 of Set 6 | kapuskasing
# Processing Record 39 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 40 of Set 6 | majdanpek
# Processing Record 41 of Set 6 | sungai raya
# Processing Record 42 of Set 6 | aasiaat
# Processing Record 43 of Set 6 | siverek
# Processing Record 44 of Set 6 | el calafate
# Processing Record 45 of Set 6 | ati
# Processing Record 46 of Set 6 | nar'yan-mar
# Processing Record 47 of Set 6 | yangshuo
# Processing Record 48 of Set 6 | nuku'alofa
# Processing Record 49 of Set 6 | mahibadhoo
# Processing Record 0 of Set 7 | monteria
# Processing Record 1 of Set 7 | morozovsk
# Processing Record 2 of Set 7 | nemuro
# Processing Record 3 of Set 7 | sabratah
# Processing Record 4 of Set 7 | whangarei
# Processing Record 5 of Set 7 | gamba
# Processing Record 6 of Set 7 | argo
# Processing Record 7 of Set 7 | pacific grove
# Processing Record 8 of Set 7 | bargaal
# Processing Record 9 of Set 7 | daru
# Processing Record 10 of Set 7 | majene
# Processing Record 11 of Set 7 | melfort
# Processing Record 12 of Set 7 | sorong
# Processing Record 13 of Set 7 | luderitz
# Processing Record 14 of Set 7 | ribeira grande
# Processing Record 15 of Set 7 | ban phe
# City not found. Skipping...
# Processing Record 16 of Set 7 | upata
# Processing Record 17 of Set 7 | kill devil hills
# Processing Record 18 of Set 7 | saudarkrokur
# Processing Record 19 of Set 7 | flying fish cove
# Processing Record 20 of Set 7 | pathein
# Processing Record 21 of Set 7 | lihue
# Processing Record 22 of Set 7 | rawson
# Processing Record 23 of Set 7 | ust-nera
# Processing Record 24 of Set 7 | newman
# Processing Record 25 of Set 7 | berea
# Processing Record 26 of Set 7 | turkmenbasy
# Processing Record 27 of Set 7 | tshikapa
# Processing Record 28 of Set 7 | belle fourche
# Processing Record 29 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 7 | jamestown
# Processing Record 31 of Set 7 | yaren
# Processing Record 32 of Set 7 | pontivy
# Processing Record 33 of Set 7 | santa elena de uairen
# Processing Record 34 of Set 7 | puerto baquerizo moreno
# Processing Record 35 of Set 7 | el granada
# Processing Record 36 of Set 7 | kenai
# Processing Record 37 of Set 7 | kaukauna
# Processing Record 38 of Set 7 | balikpapan
# Processing Record 39 of Set 7 | barkly west
# Processing Record 40 of Set 7 | geraldton
# Processing Record 41 of Set 7 | baoro
# Processing Record 42 of Set 7 | grootfontein
# Processing Record 43 of Set 7 | urengoy
# Processing Record 44 of Set 7 | baberu
# Processing Record 45 of Set 7 | attur
# Processing Record 46 of Set 7 | buka
# Processing Record 47 of Set 7 | mizdah
# Processing Record 48 of Set 7 | winejok
# City not found. Skipping...
# Processing Record 49 of Set 7 | kingston
# Processing Record 0 of Set 8 | anloga
# Processing Record 1 of Set 8 | kilindoni
# Processing Record 2 of Set 8 | labrador city
# Processing Record 3 of Set 8 | gagra
# Processing Record 4 of Set 8 | soio
# Processing Record 5 of Set 8 | jaisalmer
# Processing Record 6 of Set 8 | usinsk
# Processing Record 7 of Set 8 | kuanda
# Processing Record 8 of Set 8 | susuman
# Processing Record 9 of Set 8 | usogorsk
# Processing Record 10 of Set 8 | madimba
# Processing Record 11 of Set 8 | shemgang
# Processing Record 12 of Set 8 | vilyuchinsk
# Processing Record 13 of Set 8 | rio grande
# Processing Record 14 of Set 8 | tsiombe
# Processing Record 15 of Set 8 | maughold
# Processing Record 16 of Set 8 | bhigvan
# Processing Record 17 of Set 8 | warora
# Processing Record 18 of Set 8 | elliot lake
# Processing Record 19 of Set 8 | nacala
# Processing Record 20 of Set 8 | badger
# Processing Record 21 of Set 8 | goroka
# Processing Record 22 of Set 8 | frenda
# Processing Record 23 of Set 8 | shingu
# Processing Record 24 of Set 8 | vilyuysk
# Processing Record 25 of Set 8 | chernyanka
# Processing Record 26 of Set 8 | vernon
# Processing Record 27 of Set 8 | sroda slaska
# Processing Record 28 of Set 8 | sao vicente
# Processing Record 29 of Set 8 | capayan
# Processing Record 30 of Set 8 | tabou
# Processing Record 31 of Set 8 | kuching
# Processing Record 32 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 33 of Set 8 | stornoway
# Processing Record 34 of Set 8 | ritchie
# Processing Record 35 of Set 8 | walvis bay
# Processing Record 36 of Set 8 | labuan
# Processing Record 37 of Set 8 | mahanje
# Processing Record 38 of Set 8 | port alfred
# Processing Record 39 of Set 8 | kurchum
# Processing Record 40 of Set 8 | coquimbo
# Processing Record 41 of Set 8 | ammanford
# Processing Record 42 of Set 8 | gazojak
# Processing Record 43 of Set 8 | zherdevka
# Processing Record 44 of Set 8 | vallegrande
# Processing Record 45 of Set 8 | winnemucca
# Processing Record 46 of Set 8 | clearwater
# Processing Record 47 of Set 8 | olyokminsk
# Processing Record 48 of Set 8 | castlegar
# Processing Record 49 of Set 8 | grand-bassam
# Processing Record 0 of Set 9 | hilo
# Processing Record 1 of Set 9 | chaah
# Processing Record 2 of Set 9 | alto barinas
# Processing Record 3 of Set 9 | chiras
# Processing Record 4 of Set 9 | gadzhiyevo
# Processing Record 5 of Set 9 | geroskipou
# City not found. Skipping...
# Processing Record 6 of Set 9 | vila velha
# Processing Record 7 of Set 9 | asadabad
# Processing Record 8 of Set 9 | canete
# Processing Record 9 of Set 9 | youkounkoun
# Processing Record 10 of Set 9 | olgii
# City not found. Skipping...
# Processing Record 11 of Set 9 | maragogi
# Processing Record 12 of Set 9 | kourou
# Processing Record 13 of Set 9 | bejaia
# Processing Record 14 of Set 9 | manismata
# Processing Record 15 of Set 9 | forbes
# Processing Record 16 of Set 9 | saratamata
# City not found. Skipping...
# Processing Record 17 of Set 9 | chepen
# Processing Record 18 of Set 9 | playas
# Processing Record 19 of Set 9 | mulki
# Processing Record 20 of Set 9 | oualidia
# City not found. Skipping...
# Processing Record 21 of Set 9 | richards bay
# Processing Record 22 of Set 9 | aldama
# Processing Record 23 of Set 9 | zhosaly
# Processing Record 24 of Set 9 | bereket
# Processing Record 25 of Set 9 | port hedland
# Processing Record 26 of Set 9 | zheleznodorozhnyy
# Processing Record 27 of Set 9 | laguna
# Processing Record 28 of Set 9 | iranshahr
# Processing Record 29 of Set 9 | illapel
# Processing Record 30 of Set 9 | alofi
# Processing Record 31 of Set 9 | howard springs
# Processing Record 32 of Set 9 | jieshi
# Processing Record 33 of Set 9 | dawson creek
# Processing Record 34 of Set 9 | as sulayyil
# Processing Record 35 of Set 9 | hotan
# Processing Record 36 of Set 9 | bamboo flat
# Processing Record 37 of Set 9 | thurso
# Processing Record 38 of Set 9 | sabang
# Processing Record 39 of Set 9 | tan-tan
# Processing Record 40 of Set 9 | mto wa mbu
# Processing Record 41 of Set 9 | bolbec
# Processing Record 42 of Set 9 | minas de marcona
# Processing Record 43 of Set 9 | palmer
# Processing Record 44 of Set 9 | antakotako
# City not found. Skipping...
# Processing Record 45 of Set 9 | berezovyy
# Processing Record 46 of Set 9 | dunlap
# Processing Record 47 of Set 9 | palikir - national government center
# Processing Record 48 of Set 9 | carrizo springs
# Processing Record 49 of Set 9 | pallasovka
# Processing Record 0 of Set 10 | aykhal
# Processing Record 1 of Set 10 | nola
# Processing Record 2 of Set 10 | muravlenko
# Processing Record 3 of Set 10 | ust'-charyshskaya pristan'
# Processing Record 4 of Set 10 | seogwipo
# City not found. Skipping...
# Processing Record 5 of Set 10 | balurghat
# Processing Record 6 of Set 10 | kerikeri
# Processing Record 7 of Set 10 | yauya
# Processing Record 8 of Set 10 | primorskiy
# Processing Record 9 of Set 10 | afonso claudio
# Processing Record 10 of Set 10 | mesquite
# Processing Record 11 of Set 10 | kani keli
# Processing Record 12 of Set 10 | trujillo
# Processing Record 13 of Set 10 | albania
# Processing Record 14 of Set 10 | manta
# Processing Record 15 of Set 10 | nabire
# Processing Record 16 of Set 10 | porto novo
# Processing Record 17 of Set 10 | mejit
# Processing Record 18 of Set 10 | nova vicosa
# Processing Record 19 of Set 10 | norilsk
# Processing Record 20 of Set 10 | zapala
# Processing Record 21 of Set 10 | tofol
# Processing Record 22 of Set 10 | ginir
# Processing Record 23 of Set 10 | tokar
# Processing Record 24 of Set 10 | nili
# Processing Record 25 of Set 10 | praia da vitoria
# Processing Record 26 of Set 10 | chelm
# Processing Record 27 of Set 10 | colotlan
# Processing Record 28 of Set 10 | tosontsengel
# Processing Record 29 of Set 10 | cabedelo
# Processing Record 30 of Set 10 | charters towers
# Processing Record 31 of Set 10 | miri
# Processing Record 32 of Set 10 | kailua-kona
# Processing Record 33 of Set 10 | oum hadjer
# Processing Record 34 of Set 10 | taltal
# Processing Record 35 of Set 10 | farafangana
# Processing Record 36 of Set 10 | xacmaz
# Processing Record 37 of Set 10 | sinabang
# Processing Record 38 of Set 10 | mariinsk
# Processing Record 39 of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 40 of Set 10 | funafuti
# Processing Record 41 of Set 10 | bishkul
# Processing Record 42 of Set 10 | zahedan
# Processing Record 43 of Set 10 | belmonte
# Processing Record 44 of Set 10 | kupang
# Processing Record 45 of Set 10 | edd
# Processing Record 46 of Set 10 | autazes
# Processing Record 47 of Set 10 | sovetskaya gavan'
# Processing Record 48 of Set 10 | la ronge
# Processing Record 49 of Set 10 | chapaev
# Processing Record 0 of Set 11 | minneola
# Processing Record 1 of Set 11 | ust'-ilimsk
# Processing Record 2 of Set 11 | port macquarie
# Processing Record 3 of Set 11 | chongwe
# Processing Record 4 of Set 11 | san felipe
# Processing Record 5 of Set 11 | logansport
# Processing Record 6 of Set 11 | phan rang-thap cham
# Processing Record 7 of Set 11 | shelbyville
# Processing Record 8 of Set 11 | uzunkopru
# City not found. Skipping...
# Processing Record 9 of Set 11 | harlingen
# Processing Record 10 of Set 11 | swift current
# Processing Record 11 of Set 11 | benguela
# Processing Record 12 of Set 11 | ephraim
# Processing Record 13 of Set 11 | prince rupert
# Processing Record 14 of Set 11 | mwene-ditu
# Processing Record 15 of Set 11 | atafu village
# Processing Record 16 of Set 11 | cadale
# Processing Record 17 of Set 11 | novodvinsk
# Processing Record 18 of Set 11 | matiari
# Processing Record 19 of Set 11 | hanzhong
# Processing Record 20 of Set 11 | flin flon
# Processing Record 21 of Set 11 | bonthe
# Processing Record 22 of Set 11 | chernushka
# Processing Record 23 of Set 11 | berezovo
# Processing Record 24 of Set 11 | portland
# Processing Record 25 of Set 11 | santa rosa de lima
# Processing Record 26 of Set 11 | vanimo
# Processing Record 27 of Set 11 | carlos chagas
# Processing Record 28 of Set 11 | novyy urgal
# Processing Record 29 of Set 11 | ponta delgada
# Processing Record 30 of Set 11 | paraty
# Processing Record 31 of Set 11 | canutama
# Processing Record 32 of Set 11 | rahimatpur
# Processing Record 33 of Set 11 | al kharj
# Processing Record 34 of Set 11 | gornozavodsk
# Processing Record 35 of Set 11 | grand falls-windsor
# Processing Record 36 of Set 11 | tionk essil
# Processing Record 37 of Set 11 | sibi
# Processing Record 38 of Set 11 | villa gesell
# Processing Record 39 of Set 11 | waingapu
# Processing Record 40 of Set 11 | port moresby
# Processing Record 41 of Set 11 | saulkrasti
# Processing Record 42 of Set 11 | guichon
# Processing Record 43 of Set 11 | fauske
# Processing Record 44 of Set 11 | espanola
# Processing Record 45 of Set 11 | korla
# Processing Record 46 of Set 11 | coahuayana de hidalgo
# Processing Record 47 of Set 11 | caxito
# Processing Record 48 of Set 11 | posse
# Processing Record 49 of Set 11 | felipe carrillo puerto
# Processing Record 0 of Set 12 | sur
# Processing Record 1 of Set 12 | la'ie
# Processing Record 2 of Set 12 | zhigalovo
# Processing Record 3 of Set 12 | saint-francois
# Processing Record 4 of Set 12 | zhukovka
# Processing Record 5 of Set 12 | coeur d'alene
# Processing Record 6 of Set 12 | sao joao da barra
# Processing Record 7 of Set 12 | nadi
# Processing Record 8 of Set 12 | illizi
# Processing Record 9 of Set 12 | bokani
# Processing Record 10 of Set 12 | koulikoro
# Processing Record 11 of Set 12 | charqueadas
# Processing Record 12 of Set 12 | naze
# Processing Record 13 of Set 12 | ecka
# Processing Record 14 of Set 12 | as saffaniyah
# Processing Record 15 of Set 12 | piti village
# Processing Record 16 of Set 12 | kushiro
# Processing Record 17 of Set 12 | najran
# Processing Record 18 of Set 12 | yanchep
# Processing Record 19 of Set 12 | alice springs
# Processing Record 20 of Set 12 | mosjoen
# Processing Record 21 of Set 12 | errachidia
# Processing Record 22 of Set 12 | puerto asis
# Processing Record 23 of Set 12 | privas
# Processing Record 24 of Set 12 | puerto ayacucho
# Processing Record 25 of Set 12 | pechora
# Processing Record 26 of Set 12 | andreapol'
# Processing Record 27 of Set 12 | moyynkum
# Processing Record 28 of Set 12 | guerrero negro
# Processing Record 29 of Set 12 | miyako
# Processing Record 30 of Set 12 | marmaris
# Processing Record 31 of Set 12 | koryazhma
# Processing Record 32 of Set 12 | jalalpur
# Processing Record 33 of Set 12 | bardai
# Processing Record 34 of Set 12 | lompoc
# Processing Record 35 of Set 12 | tamiahua
# Processing Record 36 of Set 12 | kalmunai
# Processing Record 37 of Set 12 | pizarro
# Processing Record 38 of Set 12 | makarov
# Processing Record 39 of Set 12 | kristiansund
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data) # YOUR CODE HERE

# Show Record Count
city_data_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                  west island -12.1568   96.8225     24.99        78
# 1                  nova sintra  14.8667  -24.7167     23.23        77
# 2                        mayya  61.7333  130.2811      3.62        63
# 3       hawaiian paradise park  19.5933 -154.9731     28.91        70
# 4  edinburgh of the seven seas -37.0676  -12.3116     12.64        80
#
#    Cloudiness  Wind Speed Country        Date
# 0          40        5.14      CC  1694912881
# 1          14        3.07      CV  1694912881
# 2         100        5.11      RU  1694912882
# 3          20        4.12      US  1694912883
# 4         100       13.09      SH  1694912744

# %%
import os

# Check if the directory exists, and if not, create it
if not os.path.exists("output_data"):
    os.makedirs("output_data")

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                        west island -12.1568   96.8225     24.99        78
# 1                        nova sintra  14.8667  -24.7167     23.23        77
# 2                              mayya  61.7333  130.2811      3.62        63
# 3             hawaiian paradise park  19.5933 -154.9731     28.91        70
# 4        edinburgh of the seven seas -37.0676  -12.3116     12.64        80
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                40        5.14      CC  1694912881
# 1                14        3.07      CV  1694912881
# 2               100        5.11      RU  1694912882
# 3                20        4.12      US  1694912883
# 4               100       13.09      SH  1694912744

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.title("City Latitude vs. Max Temperature")
plt.grid(True)



# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity")
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlim(-90, 90)  # Set x-axis limits to match latitude range
plt.ylim(0, 100)   # Set y-axis limits for humidity (0-100%)
plt.axhline(0, color='black', linestyle='--', linewidth=0.7)  # Add a horizontal line at 0% humidity


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.figure(figsize=(8, 6))  # Set the figure size for better visibility
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black", alpha=0.6, cmap='coolwarm')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness")
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE
# Customize the plot appearance
plt.xlim(-90, 90)  # Set x-axis limits to match latitude range
plt.ylim(-5, 105)   # Set y-axis limits for cloudiness (-5% to 105% for better visualization)
plt.axhline(0, color='gray', linestyle='--', linewidth=0.7)  # Add a horizontal line at 0% cloudiness

# Add colorbar to represent cloudiness values
colorbar = plt.colorbar()
colorbar.set_label("Cloudiness (%)")

# Annotate specific points on the plot (optional)
# Example: Annotate a point with high cloudiness
high_cloudiness_index = city_data_df["Cloudiness"].idxmax()
plt.annotate(f'High Cloudiness: {city_data_df["Cloudiness"].max()}%', 
             (city_data_df["Lat"][high_cloudiness_index], city_data_df["Cloudiness"][high_cloudiness_index]), 
             textcoords="offset points", xytext=(0, 10), ha='center', fontsize=10, color='red')

# Customize the grid style
plt.grid(linestyle="--", alpha=0.7)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()
# Out:
# C:\Users\joey5\AppData\Local\Temp\ipykernel_5984\3946138639.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black", alpha=0.6, cmap='coolwarm')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
plt.figure(figsize=(8, 6))  # Set the figure size for better visibility
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black", alpha=0.6, cmap='coolwarm')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed")
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE
# Customize the plot appearance
plt.xlim(-90, 90)  # Set x-axis limits to match latitude range
plt.ylim(0, city_data_df["Wind Speed"].max() + 2)  # Set y-axis limits for wind speed
plt.axhline(0, color='gray', linestyle='--', linewidth=0.7)  # Add a horizontal line at 0 m/s wind speed

# Add colorbar to represent wind speed values
colorbar = plt.colorbar()
colorbar.set_label("Wind Speed (m/s)")

# Annotate specific points on the plot (optional)
# Example: Annotate a point with high wind speed
high_wind_speed_index = city_data_df["Wind Speed"].idxmax()
plt.annotate(f'High Wind Speed: {city_data_df["Wind Speed"].max()} m/s', 
             (city_data_df["Lat"][high_wind_speed_index], city_data_df["Wind Speed"][high_wind_speed_index]), 
             textcoords="offset points", xytext=(0, 10), ha='center', fontsize=10, color='red')

# Customize the grid style
plt.grid(linestyle="--", alpha=0.7)


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
# Out:
# C:\Users\joey5\AppData\Local\Temp\ipykernel_5984\1194713934.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black", alpha=0.6, cmap='coolwarm')

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
import matplotlib.pyplot as plt
from scipy.stats import linregress

def plot_linear_regression(x_values, y_values, x_label, y_label, title, annotation, fig_name):
    # Calculate the linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x_values, y_values)
    regress_values = slope * x_values + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}\nR-squared = {r_value**2:.2f}"

    # Create the scatter plot
    plt.figure(figsize=(8, 6))
    plt.scatter(x_values, y_values, edgecolors="black", alpha=0.6)
    plt.plot(x_values, regress_values, "r-", label="Linear Regression")

    # Annotate the linear regression equation on the plot
    plt.annotate(line_eq, annotation, fontsize=12, color="red")

    # Customize plot labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Customize legend
    plt.legend()

    # Save the figure as an image file
    plt.savefig(fig_name)

    # Show the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                   nova sintra  14.8667  -24.7167     23.23        77
# 2                         mayya  61.7333  130.2811      3.62        63
# 3        hawaiian paradise park  19.5933 -154.9731     28.91        70
# 6                       stanley  54.8680   -1.6985     12.38        92
# 7                        itoman  26.1247  127.6694     31.01        77
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                14        3.07      CV  1694912881
# 2               100        5.11      RU  1694912882
# 3                20        4.12      US  1694912883
# 6                75        2.06      GB  1694912884
# 7                75        5.66      JP  1694912885

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                        west island -12.1568   96.8225     24.99        78
# 4        edinburgh of the seven seas -37.0676  -12.3116     12.64        80
# 5                           waitangi -43.9535 -176.5597     14.34        83
# 8                           karratha -20.7377  116.8463     28.26        29
# 10                            maceio  -9.6658  -35.7353     24.69        88
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                40        5.14      CC  1694912881
# 4               100       13.09      SH  1694912744
# 5               100        4.47      NZ  1694912747
# 8                53        3.52      AU  1694912887
# 10               40        2.06      BR  1694912756

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"],
                       "Latitude", "Max Temperature (°C)",
                       "Northern Hemisphere - City Latitude vs. Max Temperature",
                       (10, 5), "output_data/Northern_Lat_vs_Max_Temp_Regression.png")

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"],
                       "Latitude", "Max Temperature (°C)",
                       "Southern Hemisphere - City Latitude vs. Max Temperature",
                       (-50, 25), "output_data/Southern_Lat_vs_Max_Temp_Regression.png")

# %% [markdown]
# **Discussion about the linear relationship:**
# The linear regression plots for max temperature versus latitude in both the Northern and Southern Hemispheres provide insights into the relationship between these two variables:
#
# **Northern Hemisphere:**
# In the linear regression plot for the Northern Hemisphere, there is a clear negative linear relationship between latitude and max temperature. As you move away from the equator (latitude 0°) towards higher latitudes (further from the equator), the max temperature tends to decrease. This is evident from the negative slope of the regression line. The R-squared value indicates that the linear regression model explains a significant portion of the variance in max temperature.
#
# **Southern Hemisphere:**
# In the linear regression plot for the Southern Hemisphere, there is a positive linear relationship between latitude and max temperature. As you move closer to the equator (latitude 0°) from lower latitudes (further from the South Pole), the max temperature tends to increase. This is evident from the positive slope of the regression line. The R-squared value indicates that the linear regression model explains a significant portion of the variance in max temperature.
#
# Overall, these plots clearly illustrate the relationship between latitude and max temperature in both hemispheres, with temperature generally decreasing as you move away from the equator in the Northern Hemisphere and increasing as you move towards the equator in the Southern Hemisphere. This observation aligns with the well-known fact that temperature is influenced by latitude and its proximity to the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"],
                       "Latitude", "Humidity",
                       "Northern Hemisphere - City Latitude vs. Humidity",
                       (10, 5), "output_data/Northern_Lat_vs_Humidity_Regression.png")

# %%
# Southern Hemisphere
# YOUR CODE HERE
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"],
                       "Latitude", "Humidity",
                       "Northern Hemisphere - City Latitude vs. Humidity",
                       (-50, 30), "output_data/Southern_Lat_vs_Humidity_Regression.png")

# %% [markdown]
# **Discussion about the linear relationship:**
# The linear regression plots for humidity versus latitude in both the Northern and Southern Hemispheres provide insights into the relationship between these two variables.
#
# **Northern Hemisphere:**
# In the linear regression plot for the Northern Hemisphere, there appears to be a relatively weak linear relationship between humidity and latitude. The scatter plot shows data points scattered across a range of latitudes, and the linear regression line doesn't fit the data very tightly. The slope of the regression line may be positive or negative, depending on the specific data and the location of cities. This suggests that there is no strong, consistent linear trend between humidity and latitude in the Northern Hemisphere.
#
# **Southern Hemisphere:**
# Similarly, in the linear regression plot for the Southern Hemisphere, we also see a relatively weak linear relationship between humidity and latitude. While there might be some slight upward or downward trends, the data points are scattered, and the linear regression line doesn't fit the data tightly. This implies that there is no strong, consistent linear association between humidity and latitude in the Southern Hemisphere either.
#
# Overall, these plots suggest that latitude alone may not be a strong predictor of humidity. Other factors, such as geographical location, proximity to bodies of water, and climate patterns, likely play a more significant role in determining humidity levels in different regions. To gain a more comprehensive understanding of humidity variations, a more complex analysis that considers multiple factors and regions may be necessary.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"],
                       "Latitude", "Cloudiness",
                       "Northern Hemisphere - City Latitude vs. Cloudiness",
                       (10, 5), "output_data/Northern_Lat_vs_Cloudiness_Regression.png")

# %%
# Southern Hemisphere
# YOUR CODE HERE
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"],
                       "Latitude", "Cloudiness",
                       "Northern Hemisphere - City Latitude vs. Cloudiness",
                       (-50, 30), "output_data/Northern_Lat_vs_Cloudiness_Regression.png")

# %% [markdown]
# **Discussion about the linear relationship:**
# The linear regression plots for cloudiness versus latitude in both the Northern and Southern Hemispheres can provide insights into the relationship between these two variables:
#
# **Northern Hemisphere:**
# In the linear regression plot for the Northern Hemisphere, there appears to be a very weak or almost non-existent linear relationship between cloudiness and latitude. The scatter plot shows data points widely scattered across various latitudes, and the linear regression line doesn't fit the data well. The slope of the regression line may be close to zero, indicating that there is little to no linear trend between cloudiness and latitude in the Northern Hemisphere.
#
# **Southern Hemisphere:**
# Similarly, in the linear regression plot for the Southern Hemisphere, there also appears to be a very weak or non-existent linear relationship between cloudiness and latitude. The data points are widely dispersed, and the linear regression line doesn't provide a good fit to the data. Again, the slope of the regression line may be close to zero, suggesting that cloudiness and latitude are not strongly correlated in the Southern Hemisphere.
#
# Overall, these plots suggest that latitude alone is not a strong predictor of cloudiness. Cloudiness is influenced by a variety of factors, including local weather patterns, geographical features, and climate conditions, which may not follow a simple linear relationship with latitude. To better understand cloudiness patterns, a more complex analysis that considers multiple factors and regional influences would be necessary.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"],
                       "Latitude", "Cloudiness",
                       "Northern Hemisphere - City Latitude vs. wind Speed",
                       (10, 5), "output_data/Northern_Lat_vs_wind_speed_Regression.png")

# %%
# Southern Hemisphere
# YOUR CODE HERE
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"],
                       "Latitude", "Cloudiness",
                       "Northern Hemisphere - City Latitude vs. wind Speed",
                       (-25, 13), "output_data/Northern_Lat_vs_wind_speed_Regression.png")

# %% [markdown]
# **Discussion about the linear relationship:**
# The linear regression plots for wind speed versus latitude in both the Northern and Southern Hemispheres can provide insights into the relationship between these two variables:
#
# **Northern Hemisphere:**
# In the linear regression plot for the Northern Hemisphere, there seems to be a very weak or almost non-existent linear relationship between wind speed and latitude. The scatter plot shows data points scattered widely across various latitudes, and the linear regression line doesn't fit the data well. The slope of the regression line may be close to zero, indicating that there is little to no linear trend between wind speed and latitude in the Northern Hemisphere.
#
# **Southern Hemisphere:**
# Similarly, in the linear regression plot for the Southern Hemisphere, there also appears to be a very weak or non-existent linear relationship between wind speed and latitude. The data points are widely dispersed, and the linear regression line doesn't provide a good fit to the data. Again, the slope of the regression line may be close to zero, suggesting that wind speed and latitude are not strongly correlated in the Southern Hemisphere.
#
# Overall, these plots suggest that latitude alone is not a strong predictor of wind speed. Wind speed is influenced by a variety of factors, including local geography, topography, and atmospheric conditions, which may not follow a simple linear relationship with latitude. Other meteorological factors and regional influences likely play a more significant role in determining wind speed variations. To gain a more accurate understanding of wind patterns, a more comprehensive analysis that considers multiple factors and regional dynamics would be necessary.
